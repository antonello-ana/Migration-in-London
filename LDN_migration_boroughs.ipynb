# %%
#importing libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# importing dataset
df = pd.read_csv("/Users/anaantonello/Desktop/Jupter NoteBooks/data/Ldn_polulation_born country.csv")
df.head(5)
# Out:
#    Area Code                     Name     Geography  ALL\nEstimate  \
# 0        NaN                      NaN           NaN            NaN
# 1  E12000007                   LONDON        Region     9,078,000
# 2  E13000001             Inner London  Inner London     3,651,000
# 3  E09000007                   Camden  Inner London       263,000
# 4  E09000001  City of London [Note 16  Inner London  Not Available
#
#       ALL\n+/- CI Afghanistan\nEstimate Afghanistan\n+/- CI Albania\nEstimate  \
# 0             NaN                  Asia                 NaN            Europe
# 1  Not applicable               23,000              12,000             8,000
# 2  Not applicable          Confidential        Confidential            3,000
# 3  Not applicable           No contacts         No contacts      Confidential
# 4   Not Available         Not Available       Not Available     Not Available
#
#   Albania\n+/- CI Algeria\nEstimate  ... Kazakhstan\nEstimate  \
# ...

# %% [markdown]
# ## Renaming columns and dropping unecessary

# %%
df.rename(columns = {'Name':"Borough"}, inplace=True)
df.drop(columns = ['Area Code', 'ALL\n+/- CI'], axis = 1, inplace = True)
df.head(5)
# Out:
#                    Borough     Geography  ALL\nEstimate Afghanistan\nEstimate  \
# 0                      NaN           NaN            NaN                  Asia
# 1                   LONDON        Region     9,078,000                23,000
# 2             Inner London  Inner London     3,651,000           Confidential
# 3                   Camden  Inner London       263,000            No contacts
# 4  City of London [Note 16  Inner London  Not Available         Not Available
#
#   Afghanistan\n+/- CI Albania\nEstimate Albania\n+/- CI Algeria\nEstimate  \
# 0                 NaN            Europe             NaN            Africa
# 1             12,000             8,000           7,000             9,000
# 2        Confidential            3,000           5,000             4,000
# 3         No contacts      Confidential    Confidential       No contacts
# 4       Not Available     Not Available   Not Available     Not Available
#
# ...

# %% [markdown]
# ## Editing values
#
# ### editing strings of a specific cell

# %%
df.at[0, 'Geography'] = 'Continent'
df.head(5)
# Out:
#                    Borough     Geography  ALL\nEstimate Afghanistan\nEstimate  \
# 0                      NaN     Continent            NaN                  Asia
# 1                   LONDON        Region     9,078,000                23,000
# 2             Inner London  Inner London     3,651,000           Confidential
# 3                   Camden  Inner London       263,000            No contacts
# 4  City of London [Note 16  Inner London  Not Available         Not Available
#
#   Afghanistan\n+/- CI Albania\nEstimate Albania\n+/- CI Algeria\nEstimate  \
# 0                 NaN            Europe             NaN            Africa
# 1             12,000             8,000           7,000             9,000
# 2        Confidential            3,000           5,000             4,000
# 3         No contacts      Confidential    Confidential       No contacts
# 4       Not Available     Not Available   Not Available     Not Available
#
# ...

# %% [markdown]
# ### editing numbers
#
# removing commas
#
# replace strings for NA
#
# convert obj to floats

# %%
# Remove commas from numbers

for col in df.columns[2:]:
    df[col] = df[col].str.replace(',', '', regex=False)
    
df.head()
# Out:
#                    Borough     Geography  ALL\nEstimate Afghanistan\nEstimate  \
# 0                      NaN     Continent            NaN                  Asia
# 1                   LONDON        Region       9078000                 23000
# 2             Inner London  Inner London       3651000           Confidential
# 3                   Camden  Inner London        263000            No contacts
# 4  City of London [Note 16  Inner London  Not Available         Not Available
#
#   Afghanistan\n+/- CI Albania\nEstimate Albania\n+/- CI Algeria\nEstimate  \
# 0                 NaN            Europe             NaN            Africa
# 1              12000              8000            7000              9000
# 2        Confidential             3000            5000              4000
# 3         No contacts      Confidential    Confidential       No contacts
# 4       Not Available     Not Available   Not Available     Not Available
#
# ...

# %%
# Replace text to NA to trnasform numbers in int 

df.replace({"Not applicable": pd.NA, "No contacts": pd.NA, "Confidential": pd.NA}, inplace=True)
df.head()
# Out:
#                    Borough     Geography  ALL\nEstimate Afghanistan\nEstimate  \
# 0                      NaN     Continent            NaN                  Asia
# 1                   LONDON        Region       9078000                 23000
# 2             Inner London  Inner London       3651000                   <NA>
# 3                   Camden  Inner London        263000                   <NA>
# 4  City of London [Note 16  Inner London  Not Available         Not Available
#
#   Afghanistan\n+/- CI Albania\nEstimate Albania\n+/- CI Algeria\nEstimate  \
# 0                 NaN            Europe             NaN            Africa
# 1              12000              8000            7000              9000
# 2                <NA>             3000            5000              4000
# 3                <NA>              <NA>            <NA>              <NA>
# 4       Not Available     Not Available   Not Available     Not Available
#
# ...

# %%
df.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 197 columns):
#  #    Column                                   Dtype
# ---   ------                                   -----
#  0    Borough                                  object
#  1    Geography                                object
#  2    ALL
# Estimate                             object
#  3    Afghanistan
# Estimate                     object
#  4    Afghanistan
# +/- CI                       object
#  5    Albania
# Estimate                         object
#  6    Albania
# +/- CI                           object
#  7    Algeria
# Estimate                         object
#  8    Algeria
# +/- CI                           object
#  9    Angola
# Estimate                          object
#  10   Angola
# +/- CI                            object
#  11   Anguilla
# Estimate                        object
#  12   Anguilla
# +/- CI                          object
#  13   Antigua and Barbuda
# ...

# %%
# Convert columns to numeric type, which will convert non-convertible values to NaN
df_num = df

for col in df.columns[2:]:
    df[col] = pd.to_numeric(df[col], errors='coerce')
    
df_num.head()
# Out:
#                    Borough     Geography  ALL\nEstimate  \
# 0                      NaN     Continent            NaN
# 1                   LONDON        Region      9078000.0
# 2             Inner London  Inner London      3651000.0
# 3                   Camden  Inner London       263000.0
# 4  City of London [Note 16  Inner London            NaN
#
#    Afghanistan\nEstimate  Afghanistan\n+/- CI  Albania\nEstimate  \
# 0                    NaN                  NaN                NaN
# 1                23000.0              12000.0             8000.0
# 2                    NaN                  NaN             3000.0
# 3                    NaN                  NaN                NaN
# 4                    NaN                  NaN                NaN
#
#    Albania\n+/- CI  Algeria\nEstimate  Algeria\n+/- CI  Angola\nEstimate  ...  \
# 0              NaN                NaN              NaN               NaN  ...
# ...

# %%
df_num.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 197 columns):
#  #    Column                                   Dtype
# ---   ------                                   -----
#  0    Borough                                  object
#  1    Geography                                object
#  2    ALL
# Estimate                             float64
#  3    Afghanistan
# Estimate                     float64
#  4    Afghanistan
# +/- CI                       float64
#  5    Albania
# Estimate                         float64
#  6    Albania
# +/- CI                           float64
#  7    Algeria
# Estimate                         float64
#  8    Algeria
# +/- CI                           float64
#  9    Angola
# Estimate                          float64
#  10   Angola
# +/- CI                            float64
#  11   Anguilla
# Estimate                        float64
#  12   Anguilla
# +/- CI                          float64
# ...

# %%
#set boroughs as index

df_num.set_index('Borough', inplace = True)

df_num = df_num[~df_num.index.isin(['LONDON', 'Inner London', 'Outer London'])]
df_num.sort_index
df_num.head(36)
# Out:
#                             Geography  ALL\nEstimate  Afghanistan\nEstimate  \
# Borough
# NaN                         Continent            NaN                    NaN
# Camden                   Inner London       263000.0                    NaN
# City of London [Note 16  Inner London            NaN                    NaN
# Hackney                  Inner London       290000.0                    NaN
# Hammersmith and Fulham   Inner London       180000.0                    NaN
# Haringey                 Inner London       282000.0                    NaN
# Islington                Inner London       243000.0                    NaN
# Kensington and Chelsea   Inner London       153000.0                    NaN
# Lambeth                  Inner London       330000.0                    NaN
# Lewisham                 Inner London       313000.0                    NaN
# Newham                   Inner London       363000.0                    NaN
# ...

# %%
df_num.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34 entries, nan to Waltham Forest
# Data columns (total 196 columns):
#  #    Column                                   Dtype
# ---   ------                                   -----
#  0    Geography                                object
#  1    ALL
# Estimate                             float64
#  2    Afghanistan
# Estimate                     float64
#  3    Afghanistan
# +/- CI                       float64
#  4    Albania
# Estimate                         float64
#  5    Albania
# +/- CI                           float64
#  6    Algeria
# Estimate                         float64
#  7    Algeria
# +/- CI                           float64
#  8    Angola
# Estimate                          float64
#  9    Angola
# +/- CI                            float64
#  10   Anguilla
# Estimate                        float64
#  11   Anguilla
# +/- CI                          float64
#  12   Antigua and Barbuda
# Estimate             float64
# ...

# %%
df_num = df_num.dropna(subset = df_num.columns[2:], how= 'all')
df_num.sample(4)
# Out:
#                          Geography  ALL\nEstimate  Afghanistan\nEstimate  \
# Borough
# Barking and Dagenham  Outer London       223000.0                    NaN
# Redbridge             Outer London       315000.0                    NaN
# Camden                Inner London       263000.0                    NaN
# Lewisham              Inner London       313000.0                    NaN
#
#                       Afghanistan\n+/- CI  Albania\nEstimate  Albania\n+/- CI  \
# Borough
# Barking and Dagenham                  NaN                NaN              NaN
# Redbridge                             NaN                NaN              NaN
# Camden                                NaN                NaN              NaN
# Lewisham                              NaN                NaN              NaN
#
#                       Algeria\nEstimate  Algeria\n+/- CI  Angola\nEstimate  \
# Borough
# Barking and Dagenham                NaN              NaN               NaN
# ...

# %%
# Change columns names

df_num.rename(columns = {'Geography' : 'Region', 'ALL\nEstimate': 'Total'}, inplace = True)


# Remove \Estimate from columns names

df_num.columns = df_num.columns.str.replace('\nEstimate', '')


df_num.head(2)
# Out:
#                Region     Total  Afghanistan  Afghanistan\n+/- CI  Albania  \
# Borough
# Camden   Inner London  263000.0          NaN                  NaN      NaN
# Hackney  Inner London  290000.0          NaN                  NaN      NaN
#
#          Albania\n+/- CI  Algeria  Algeria\n+/- CI  Angola  Angola\n+/- CI  \
# Borough
# Camden               NaN      NaN              NaN     NaN             NaN
# Hackney              NaN      NaN              NaN     NaN             NaN
#
#          ...  Kazakhstan  Kazakhstan\n+/- CI  Kenya  Kenya\n+/- CI  Kiribati  \
# Borough  ...
# Camden   ...         NaN                 NaN    NaN            NaN       NaN
# Hackney  ...         NaN                 NaN    NaN            NaN       NaN
#
#          Kiribati\n+/- CI  Kosovo  Kosovo\n+/- CI  Kuwait  Kuwait\n+/- CI
# Borough
# Camden                NaN  3000.0          5000.0     NaN             NaN
# Hackney               NaN     NaN             NaN     NaN             NaN
#
# ...

# %%
for col in df_num.columns:
    if 'CI' in col:
        del df_num[col]
        
df_num.head(2)
# Out:
#                Region     Total  Afghanistan  Albania  Algeria  Angola  \
# Borough
# Camden   Inner London  263000.0          NaN      NaN      NaN     NaN
# Hackney  Inner London  290000.0          NaN      NaN      NaN     NaN
#
#          Anguilla  Antigua and Barbuda  Argentina  Armenia  ...    Italy  \
# Borough                                                     ...
# Camden        NaN                  NaN        NaN      NaN  ...  11000.0
# Hackney       NaN                  NaN        NaN      NaN  ...   6000.0
#
#          Ivory Coast  Jamaica   Japan  Jordan  Kazakhstan  Kenya  Kiribati  \
# Borough
# Camden           NaN      NaN  4000.0     NaN         NaN    NaN       NaN
# Hackney          NaN   4000.0     NaN     NaN         NaN    NaN       NaN
#
#          Kosovo  Kuwait
# Borough
# Camden   3000.0     NaN
# Hackney     NaN     NaN
#
# [2 rows x 99 columns]

# %%
df_melted = df_num.reset_index()
df_melted = df_melted.melt(id_vars=['Borough', 'Region', 'Total'], var_name = 'Country of Birth', value_name = 'Estimate')

df_melted = df_melted[['Borough', 'Region', 'Total', 'Country of Birth', 'Estimate']]
df_melted.set_index('Borough', inplace=True)

df_melted['Proportion_estimate'] = df_melted['Estimate']/df_melted['Total']
df_melted.head()
# Out:
#                               Region     Total Country of Birth  Estimate  \
# Borough
# Camden                  Inner London  263000.0      Afghanistan       NaN
# Hackney                 Inner London  290000.0      Afghanistan       NaN
# Hammersmith and Fulham  Inner London  180000.0      Afghanistan       NaN
# Haringey                Inner London  282000.0      Afghanistan       NaN
# Islington               Inner London  243000.0      Afghanistan       NaN
#
#                         Proportion_estimate
# Borough
# Camden                                  NaN
# Hackney                                 NaN
# Hammersmith and Fulham                  NaN
# Haringey                                NaN
# Islington                               NaN

# %%
df_melted.to_csv("/Users/anaantonello/Desktop/Jupter NoteBooks/data/Ldn_polulation_country_clean.csv")

# %%
# Average

# avg_ldn_abs = 
# avg_ldn_pr = 

# avg_bgh_abs
# avg_bgh_pr

# %% [markdown]
# # Charts

# %%
# Melt the coutry columns to one column 'Country of Birth'

df_melted = df_melted.reset_index()
df_melted.sample(5)
# Out:
#                    Borough        Region     Total        Country of Birth  \
# 1661  Richmond upon Thames  Outer London  200000.0                Dominica
# 1782                Harrow  Outer London  251000.0                   Egypt
# 367                 Bexley  Outer London  254000.0              Azerbaijan
# 763                 Merton  Outer London  210000.0  Bosnia and Herzegovina
# 2570         Tower Hamlets  Inner London  328000.0                 Hungary
#
#       Estimate  Proportion_estimate
# 1661       NaN                  NaN
# 1782       NaN                  NaN
# 367        NaN                  NaN
# 763        NaN                  NaN
# 2570   12000.0             0.036585

# %% [markdown]
# ### What is the borough with proportionaly more immigrants?

# %%
df_imm = df_melted[['Borough', 'Proportion_estimate']].dropna()

df_imm = df_imm.groupby('Borough').sum()

df_imm = df_imm.sort_values(by = 'Proportion_estimate', ascending = False)

df_imm.head(5)
# Out:
#                         Proportion_estimate
# Borough
# Brent                              0.237952
# Harrow                             0.219124
# Hounslow                           0.218182
# Kensington and Chelsea             0.215686
# Tower Hamlets                      0.207317

# %%
plt.figure(figsize = (6,8))

plt.barh(df_imm.index, df_imm['Proportion_estimate'], color = 'cornflowerblue')

plt.xlabel('Proportion of people born outside UK')
plt.ylabel('Borough of London')
plt.title('Proportion of immigrants by borough')

# Add the value to the bar
for index, value in enumerate(df_imm['Proportion_estimate']):
    plt.text(value, index, f'{value: .1%}', va = 'center', size = 8)

plt.gca().invert_yaxis()

plt.show()

# %%
df_absolute = df_melted[['Borough', 'Estimate']].dropna()

df_absolute = df_absolute.groupby('Borough').sum()

df_absolute.sort_values(by = 'Estimate', ascending = False, inplace = True)

df_absolute.head(5)
# Out:
#                Estimate
# Borough
# Brent           79000.0
# Tower Hamlets   68000.0
# Barnet          63000.0
# Hounslow        60000.0
# Hillingdon      57000.0

# %% [markdown]
# # Total of immigrans by borough

# %%
plt.figure(figsize = (8,6))

plt.barh(df_absolute.index, df_absolute['Estimate'])
plt.gca().invert_yaxis()

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Top migrants in each borough
#
# #### Sort countries by borough, return the name of the top country
#
# *This df (val_country) comes from the df, before meltin the countries columns into one column.

# %% [markdown]
# ### What are the most prevalent oversea nationality in each borough?

# %%
df_melted.head(2)
# Out:
#    Borough        Region     Total Country of Birth  Estimate  \
# 0   Camden  Inner London  263000.0      Afghanistan       NaN
# 1  Hackney  Inner London  290000.0      Afghanistan       NaN
#
#    Proportion_estimate
# 0                  NaN
# 1                  NaN

# %%
# Calculate the total of immigrants in each borough
total_immigr = df_melted.groupby('Borough')['Estimate'].sum().reset_index()
total_immigr.rename(columns = {'Estimate':'Total_immigr'}, inplace = True)
total_immigr.head()
# Out:
#                 Borough  Total_immigr
# 0  Barking and Dagenham       35000.0
# 1                Barnet       63000.0
# 2                Bexley       18000.0
# 3                 Brent       79000.0
# 4               Bromley       18000.0

# %%
# Add this series back to the df_melted df (merge)
df_melted = pd.merge(df_melted, total_immigr, on = 'Borough')
df_melted.head()
# Out:
#   Borough        Region     Total Country of Birth  Estimate  \
# 0  Camden  Inner London  263000.0      Afghanistan       NaN
# 1  Camden  Inner London  263000.0          Albania       NaN
# 2  Camden  Inner London  263000.0          Algeria       NaN
# 3  Camden  Inner London  263000.0           Angola       NaN
# 4  Camden  Inner London  263000.0         Anguilla       NaN
#
#    Proportion_estimate  Total_immigr
# 0                  NaN       51000.0
# 1                  NaN       51000.0
# 2                  NaN       51000.0
# 3                  NaN       51000.0
# 4                  NaN       51000.0

# %%
# Proportion of immigrants in each borough

df_melted['Prop_immigr'] = df_melted['Total_immigr']/df_melted['Total']
df_melted.head()
# Out:
#   Borough        Region     Total Country of Birth  Estimate  \
# 0  Camden  Inner London  263000.0      Afghanistan       NaN
# 1  Camden  Inner London  263000.0          Albania       NaN
# 2  Camden  Inner London  263000.0          Algeria       NaN
# 3  Camden  Inner London  263000.0           Angola       NaN
# 4  Camden  Inner London  263000.0         Anguilla       NaN
#
#    Proportion_estimate  Total_immigr  Prop_immigr
# 0                  NaN       51000.0     0.193916
# 1                  NaN       51000.0     0.193916
# 2                  NaN       51000.0     0.193916
# 3                  NaN       51000.0     0.193916
# 4                  NaN       51000.0     0.193916

# %%
# Reorder columns

new_cols_order = ['Borough','Region','Total', 'Total_immigr', 'Prop_immigr', 'Country of Birth', 'Estimate', 'Proportion_estimate']
df_melted = df_melted[new_cols_order]
df_melted.head()
# Out:
#   Borough        Region     Total  Total_immigr  Prop_immigr Country of Birth  \
# 0  Camden  Inner London  263000.0       51000.0     0.193916      Afghanistan
# 1  Camden  Inner London  263000.0       51000.0     0.193916          Albania
# 2  Camden  Inner London  263000.0       51000.0     0.193916          Algeria
# 3  Camden  Inner London  263000.0       51000.0     0.193916           Angola
# 4  Camden  Inner London  263000.0       51000.0     0.193916         Anguilla
#
#    Estimate  Proportion_estimate
# 0       NaN                  NaN
# 1       NaN                  NaN
# 2       NaN                  NaN
# 3       NaN                  NaN
# 4       NaN                  NaN

# %%
# Drop NaN from 'Proportion' values
df_melted = df_melted.dropna(subset=['Proportion_estimate'])

# Find the row (index) with the maximum proportion for each borough to filter
max_indices = df_melted.groupby('Borough')['Proportion_estimate'].idxmax()

# Filter the rows with the maximum proportions
max_proportion = df_melted.loc[max_indices]

# Sort the resulting DataFrame by 'Proportion' in descending order
max_proportion = max_proportion.sort_values(by='Proportion_estimate', ascending=False).reset_index(drop = True)

# Display the DataFrame with the maximum proportions
max_proportion.head(5)
# Out:
#          Borough        Region     Total  Total_immigr  Prop_immigr  \
# 0       Hounslow  Outer London  275000.0       60000.0     0.218182
# 1          Brent  Outer London  332000.0       79000.0     0.237952
# 2         Harrow  Outer London  251000.0       55000.0     0.219124
# 3     Hillingdon  Outer London  314000.0       57000.0     0.181529
# 4  Tower Hamlets  Inner London  328000.0       68000.0     0.207317
#
#   Country of Birth  Estimate  Proportion_estimate
# 0            India   46000.0             0.167273
# 1            India   44000.0             0.132530
# 2            India   30000.0             0.119522
# 3            India   32000.0             0.101911
# 4       Bangladesh   33000.0             0.100610

# %%
# Drop NaN from 'Proportion' values
df_melted = df_melted.dropna(subset=['Proportion_estimate'])

# Find the row (index) with the maximum proportion for each borough to filter
max_indices = df_melted.groupby('Borough')['Proportion_estimate'].idxmax()

# Filter the rows with the maximum proportions
max_proportion = df_melted.loc[max_indices]


# Sort the resulting DataFrame by 'Proportion' in descending order
max_proportion = max_proportion.sort_values(by='Proportion_estimate', ascending=False).reset_index(drop = True)

# Display the DataFrame with the maximum proportions
max_proportion.head(5)
# Out:
#          Borough        Region     Total  Total_immigr  Prop_immigr  \
# 0       Hounslow  Outer London  275000.0       60000.0     0.218182
# 1          Brent  Outer London  332000.0       79000.0     0.237952
# 2         Harrow  Outer London  251000.0       55000.0     0.219124
# 3     Hillingdon  Outer London  314000.0       57000.0     0.181529
# 4  Tower Hamlets  Inner London  328000.0       68000.0     0.207317
#
#   Country of Birth  Estimate  Proportion_estimate
# 0            India   46000.0             0.167273
# 1            India   44000.0             0.132530
# 2            India   30000.0             0.119522
# 3            India   32000.0             0.101911
# 4       Bangladesh   33000.0             0.100610

# %%
colors = {'Outer London' : "#9ecae1", "Inner London" : "#3182bd"}

plt.figure(figsize = (6,10))

bar_max = plt.barh(max_proportion['Borough'], max_proportion['Proportion_estimate'], color = max_proportion['Region'].map(colors))

# Titles
plt.ylabel('Borough of London')
plt.title('Top immigrant nationality in each borough of London')

# Add the value to the bar
for bar, country, proportion in zip(bar_max, max_proportion['Country of Birth'], max_proportion['Proportion_estimate']):
    plt.text(bar.get_width(), bar.get_y() + bar.get_height()/2, f'{country} - {proportion: .1%}',
             va = 'center', ha = 'left', fontsize = 8, color = 'black')

plt.gca().invert_yaxis()

plt.show()

# %%
# Calculate the remaining proportion to complete 100% in 2 new columns (['Immigrant_remaining'] and ['total_remaining'])

max_proportion['Immigrant_remaining'] = max_proportion['Prop_immigr'] - max_proportion['Proportion_estimate']
max_proportion['total_remaining'] = 1 - max_proportion['Prop_immigr']
max_proportion.head()
# Out:
#          Borough        Region     Total  Total_immigr  Prop_immigr  \
# 0       Hounslow  Outer London  275000.0       60000.0     0.218182
# 1          Brent  Outer London  332000.0       79000.0     0.237952
# 2         Harrow  Outer London  251000.0       55000.0     0.219124
# 3     Hillingdon  Outer London  314000.0       57000.0     0.181529
# 4  Tower Hamlets  Inner London  328000.0       68000.0     0.207317
#
#   Country of Birth  Estimate  Proportion_estimate  Immigrant_remaining  \
# 0            India   46000.0             0.167273             0.050909
# 1            India   44000.0             0.132530             0.105422
# 2            India   30000.0             0.119522             0.099602
# 3            India   32000.0             0.101911             0.079618
# 4       Bangladesh   33000.0             0.100610             0.106707
#
#    total_remaining
# 0         0.781818
# 1         0.762048
# 2         0.780876
# 3         0.818471
# 4         0.792683

# %%
colors = {'Outer London': "#9ecae1", "Inner London": "#3182bd"}


plt.figure(figsize=(8, 10))

# Plot Proportion bars (blue)
bar_max = plt.barh(max_proportion['Borough'], max_proportion['Proportion_estimate'], color = max_proportion['Region'].map(colors))

# Plot remaining bars (greys)
# Dark grey for total of immigrants
plt.barh(max_proportion['Borough'], max_proportion['Immigrant_remaining'], left = max_proportion['Proportion_estimate'], color = '#d9d9d9')

# Light Grey for total of population
plt.barh(max_proportion['Borough'], max_proportion['total_remaining'], left = max_proportion['Prop_immigr'], color = '#f0f0f0')


# Titles and labels

plt.ylabel('Borough of London')
plt.title('Top immigrant nationality in each borough of London')

# Add the value to the bar
for bar, country, proportion in zip(bar_max, max_proportion['Country of Birth'], max_proportion['Proportion_estimate']):
    plt.text(bar.get_width(), bar.get_y() + bar.get_height() / 2, f'{country}: {proportion:.1%}',
             va='center', ha='left', fontsize=8, color='black')

# Add a legend for inner and outer london regions
plt.legend(handles=[plt.Rectangle((0, 0), 1, 1, color=colors['Outer London']),
                    plt.Rectangle((0, 0), 1, 1, color=colors['Inner London'])],
           labels=['Outer London', 'Inner London'])

# To remove the edges
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['left'].set_visible(False)

plt.gca().invert_yaxis()
plt.xticks([])

plt.tight_layout()
plt.show()

# %% [markdown]
# # How is the proportion distribution of immigrants?

# %% [markdown]
# Back to use df_melted df because this has all the country, not only the top immigrants ones (max_proportion)

# %%
df_melted['median_proportion'] = df_melted.groupby('Borough')['Proportion_estimate'].transform('median')
df_melted.sort_values(by = ['median_proportion', 'Borough'], ascending = False, inplace = True)
df_melted.head(2)
# Out:
#                    Borough        Region     Total  Total_immigr  Prop_immigr  \
# 1275  Barking and Dagenham  Outer London  223000.0       35000.0     0.156951
# 1301  Barking and Dagenham  Outer London  223000.0       35000.0     0.156951
#
#      Country of Birth  Estimate  Proportion_estimate  median_proportion
# 1275       Bangladesh    9000.0             0.040359           0.022422
# 1301            China    2000.0             0.008969           0.022422

# %%
borough_order = df_melted['Borough'].unique()
borough_order
# Out:
# array(['Barking and Dagenham', 'Westminster', 'Kensington and Chelsea',
#        'Camden', 'Lambeth', 'Enfield', 'Kingston upon Thames',
#        'Hillingdon', 'Wandsworth', 'Merton', 'Hackney', 'Lewisham',
#        'Islington', 'Tower Hamlets', 'Brent', 'Harrow', 'Ealing',
#        'Redbridge', 'Hammersmith and Fulham', 'Newham', 'Hounslow',
#        'Haringey', 'Waltham Forest', 'Bromley', 'Richmond upon Thames',
#        'Barnet', 'Sutton', 'Southwark', 'Bexley', 'Greenwich', 'Croydon',
#        'Havering'], dtype=object)

# %%
import seaborn as sns
from matplotlib.lines import Line2D  # This is a thing for the legend


plt.figure(figsize= (8,20))

p = sns.swarmplot(x = 'Proportion_estimate', y = 'Borough', data = df_melted, 
                  size = 4,
                 zorder = 10)


# plot the median line
sns.boxplot(showmeans=False,
            meanline=False,
            medianprops={'visible': True, 'color': 'grey', 'ls': '-', 'lw': 2},
            whiskerprops={'visible': False},
            zorder=1,
            x="median_proportion",
            y="Borough",
            data=df_melted,
            showfliers=True,
            showbox=False,
            showcaps=False,
            ax = p)

plt.title("Proportion of overseas nationalities in each borough of London")
plt.xlabel('Proportion of Immigrants')
plt.ylabel('')

# Adding a custom legend for the median line
median_line = Line2D([0], [0], color='grey', linewidth=2, label='Median')
plt.legend(handles=[median_line], loc='upper right')


plt.show()

# %% [markdown]
# ## Interactive chart

# %%
from bokeh.plotting import figure, output_notebook, show

from bokeh.transform import jitter

from bokeh.models import HoverTool, ColumnDataSource


# Ensure Bokeh plots will display in the notebook
output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a265a2a3-1833-42d5-89c5-827ec5bbd519">Loading BokehJS ...</span>
#     </div>

# %%
#df.info(verbose = True)

# %%
median_values = df_melted.groupby('Borough')['Proportion_estimate'].median().reset_index()


# Create a Bokeh figure
p = figure(width=600, height=1500, y_range=borough_order.tolist(), title="Proportion by Borough")


# Prepare data source for Bokeh --> Bokeh needs lists, ColumnDataSource treat df as lists of each column
source = ColumnDataSource(df_melted)


# Plot the swarmplot using circles
p.circle(x='Proportion_estimate', y=jitter('Borough', width=0.2, range=p.y_range), source=source, size=6, color='navy', alpha=0.3)



# Toolpit when hover the mouse over each circle
hover = HoverTool(tooltips=[
    ("Country", "@{Country of Birth}"),
    ("Borough", "@Borough"),
    ("Proportion", "@Proportion_estimate{0.2f}%")])

p.add_tools(hover)


# Labels
p.xaxis.axis_label = 'Proportion_estimate'
p.yaxis.axis_label = 'Borough'
p.title.align = "center"

show(p)
# Out:
#   <div id="c7f1b9c0-f564-43a8-a5d5-e604569f2282" data-root-id="p1862" style="display: contents;"></div>

# %%
brasil = df_melted[df_melted["Country of Birth"] == 'Brazil'].sort_values(by = 'Estimate', ascending = False)
brasil.head()
# Out:
#                      Borough        Region     Total  Total_immigr  \
# 1092              Wandsworth  Inner London  326000.0       36000.0
# 2450                Hounslow  Outer London  275000.0       60000.0
# 704                 Lewisham  Inner London  313000.0       42000.0
# 1189             Westminster  Inner London  255000.0       48000.0
# 510   Kensington and Chelsea  Inner London  153000.0       33000.0
#
#       Prop_immigr Country of Birth  Estimate  Proportion_estimate  \
# 1092     0.110429           Brazil    9000.0             0.027607
# 2450     0.218182           Brazil    6000.0             0.021818
# 704      0.134185           Brazil    5000.0             0.015974
# 1189     0.188235           Brazil    4000.0             0.015686
# 510      0.215686           Brazil    4000.0             0.026144
#
#       median_proportion  Proportion_estimate_jittered
# 1092           0.015337                      0.047920
# 2450           0.010909                     -0.012464
# ...

# %%
def countries (country_interest, col_countries, col_to_sort, df):
    result = df[df[col_countries] == country_interest].sort_values(by = col_to_sort, ascending = False)
    print(result.head())

# %%
df_melted.apply(countries, 'Brazil', 'Country of Birth', 'Estimate', df_melted)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(cls, axis)
#     513             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     514         except KeyError:
# --> 515             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 'Brazil'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /var/folders/j7/7ydlv6xx1452zht03ghykry00000gn/T/ipykernel_47113/2796806161.py in ?()
# ----> 1 df_melted.apply(countries, 'Brazil', 'Country of Birth', 'Estimate', df_melted)
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, func, axis, raw, result_type, args, **kwargs)
#    9410         2  1  2
#    9411         """
# ...
